# %% [markdown]
# <a href="https://colab.research.google.com/github/ebenitezs/PLD_NOV2020/blob/master/col_03sep2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![DATAI.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [DATAI](https://www.unav.edu/web/instituto-de-ciencia-de-los-datos-e-inteligencia-artificial/inicio)

# %% [markdown]
# $$\frac{\mathrm{dw(t)} }{\mathrm{d} t}=\frac{\lambda_0\cdot w(t) }{\left [ 1+\left ( \frac{\lambda_0}{\lambda_1 }\cdot w(t) \right )^{\psi } \right ]^{\frac{1}{\psi }}}$$

# %% [markdown]
# $$g(z)= -\frac{\left (_{2}F_{1}(1,1+\frac{1}{\psi},2+\frac{1}{\psi},(1+\left ( \frac{\lambda_0}{\lambda_1} \right )^{\psi})(z)^{\psi}\right )\left ( 1+\left ( \frac{\lambda_0}{\lambda_1} \right )^{\psi}(z)^{\psi} \right )^{1+\frac{1}{\psi}}}{1+\psi}$$

# %%
# !ls
# Out:
# dec.csv  drive	sample_data

# %%
mic=pd.read_csv('dec.csv', sep=";").head()
print(mic)
# Out:
#    run  tie  pow  pul       lis       mes       lac
# 0    1  1.0  200    0  0.142012  0.417633  0.070373
# 1   26  1.0  200   10  0.355030  2.529002  0.000000
# 2   51  1.0  200   20  0.852071  0.510441  1.102510
# 3   76  1.0  200   30  0.213018  0.672854  0.539526
# 4    6  1.0  250    0  2.958580  0.000000  1.079052

# %% [markdown]
# $$g(z)= -\frac{\left (_{2}F_{1}(1,1+\frac{1}{\psi},2+\frac{1}{\psi},(1+\left ( \frac{\lambda_0}{\lambda_1} \right )^{\psi})(z)^{\psi}\right )\left ( 1+\left ( \frac{\lambda_0}{\lambda_1} \right )^{\psi}(z)^{\psi} \right )^{1+\frac{1}{\psi}}}{1+\psi}$$]

# %% [markdown]
# #Titulo
# ##Sub titulo
# ###Capitulo
#
# ```
# #Esto tiene formato de código
# a=2+1
# a
# ```
# #Agregar hipervinculos
# [Click here](https://COLAB.RESEARCH.GOOGLE.COM)

# %%
#para usar comandos de consola utilizar el símbolo "!"
# !pip install scrapy

# %%
# !pip uninstall scrapy

# %%
#Para ver todas las librerias disponibles sin necesidad de ser instaladas
# !pip freeze

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#SUBIR ARCHIVOS USANDO DRIVE
with open('/content/gdrive/My Drive/dec.csv', 'r') as f:
    print(f.read())

# %%
#ESCRIBIR ARCHIVOS EN DRIVE
with open('/content/gdrive/My Drive/tex.txt', 'w') as f:
    f.write('escribir archivo')

# %%
#IMPORTAR ARCHIVOS DIRECTAMENTE
from google.colab import files

uploaded = files.upload()  

for filename in uploaded.keys():
    print(uploaded[filename])
# Out:
#      <input type="file" id="files-d20b343c-7439-41f8-96eb-734ac392864a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d20b343c-7439-41f8-96eb-734ac392864a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DATOS CON DECIMALES.xlsx to DATOS CON DECIMALES (1).xlsx
# ...

# %%
#EXPORTAR A LA MAQUINA LOCAL DIRECTAMENTE
with open('textofinal.txt', 'w') as f:
    f.write('Este es un texto para cargarlo directamente en la maquina local')

files.download('textofinal.txt')

# %%
# !wget http://25.io/toau/audio/sample.txt
# Out:
# --2020-09-03 11:10:28--  http://25.io/toau/audio/sample.txt
# Resolving 25.io (25.io)... 207.38.94.41, 2605:de00:1:1:4a:57:0:c0
# Connecting to 25.io (25.io)|207.38.94.41|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 282 [application/octet-stream]
# Saving to: ‘sample.txt’
#
# sample.txt          100%[===================>]     282  --.-KB/s    in 0s
#
# 2020-09-03 11:10:28 (38.3 MB/s) - ‘sample.txt’ saved [282/282]
